# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import mysql.connector

# %%
df_cust=pd.read_csv("data/customers.csv")
df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female    2     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status
# 0       358211.0        Married
# 1        65172.0         Single
# 2        22378.0        Married
# 3        33563.0        Married
# 4        39406.0        Married

# %%
df_cs=pd.read_csv("data/credit_profiles.csv")
df_trans=pd.read_csv("data/transactions.csv")

# %%
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_trans.shape
# Out:
# (500000, 7)

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
import pandas as pd

# Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",       # or your MySQL host
    user="root",
    password="root",
    database="e_master_card"
)

# %%
df_cust=pd.read_sql("select * from customers",conn)
df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female    2     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status
# 0         358211        Married
# 1          65172         Single
# 2          22378        Married
# 3          33563        Married
# 4          39406        Married

# %%
df_trans=pd.read_sql("select * from transactions",conn)
df_trans
# Out:
#         tran_id  cust_id   tran_date  tran_amount  platform  \
# 0             1      705  2023-01-01           63  Flipkart
# 1             2      385  2023-01-01           99   Alibaba
# 2             3      924  2023-01-01          471   Shopify
# 3             4      797  2023-01-01           33   Shopify
# 4             5      482  2023-01-01           68    Amazon
# ...         ...      ...         ...          ...       ...
# 499995   499996      791  2023-09-05           43    Amazon
# 499996   499997      569  2023-09-05        53022    Meesho
# 499997   499998       57  2023-09-05          224      None
# 499998   499999      629  2023-09-05          538  Flipkart
# 499999   500000      392  2023-09-05          346    Amazon
#
#           product_category payment_type
# 0              Electronics      Phonepe
# 1        Fashion & Apparel  Credit Card
# 2                   Sports      Phonepe
# 3        Fashion & Apparel         Gpay
# ...

# %%
df_cs=pd.read_sql("select * from credit_profiles",conn)
df_cs
# Out:
#       cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0           1           749            0.585171           19571.0
# 1           2           587            0.107928          161644.0
# 2           3           544            0.854807             513.0
# 3           4           504            0.336938             224.0
# 4           5           708            0.586151           18090.0
# ...       ...           ...                 ...               ...
# 999       996           564            0.702963             688.0
# 1000      997           774            0.465462           17139.0
# 1001      998           529            0.585856             386.0
# 1002      999           725            0.249670            6973.0
# 1003     1000           775            0.696050           33956.0
#
#       credit_inquiries_last_6_months  credit_limit
# 0                                0.0       40000.0
# 1                                2.0        1250.0
# ...

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    36.405000  132439.799000
# std     288.819436    15.666155  113706.313793
# min       1.000000     1.000000       0.000000
# 25%     250.750000    26.000000   42229.750000
# 50%     500.500000    32.000000  107275.000000
# 75%     750.250000    46.000000  189687.500000
# max    1000.000000   135.000000  449346.000000

# %%
df_cust.isnull().sum()
# Out:
# cust_id           0
# name              0
# gender            0
# age               0
# location          0
# occupation        0
# annual_income     0
# marital_status    0
# dtype: int64

# %%
sns.histplot(df_cust.annual_income,kde=True,color="green",label="Data")
plt.title("Histogram of annual_income")
plt.legend()
plt.show()

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    36.405000  132439.799000
# std     288.819436    15.666155  113706.313793
# min       1.000000     1.000000       0.000000
# 25%     250.750000    26.000000   42229.750000
# 50%     500.500000    32.000000  107275.000000
# 75%     750.250000    46.000000  189687.500000
# max    1000.000000   135.000000  449346.000000

# %%
df_cust[df_cust.annual_income<100]
# Out:
#      cust_id               name  gender  age location           occupation  \
# 14        15      Sanjana Malik  Female   25    Rural               Artist
# 31        32        Veer Mistry    Male   50     City       Business Owner
# 82        83  Reyansh Mukherjee    Male   27     City           Freelancer
# 97        98         Virat Puri    Male   47   Suburb       Business Owner
# 102      103         Aarav Shah    Male   32     City       Data Scientist
# 155      156       Kiaan Saxena    Male   24     City  Fullstack Developer
# 170      171       Advait Verma    Male   52     City       Business Owner
# 186      187       Samar Sardar    Male   53     City           Consultant
# 192      193        Ishan Joshi    Male   37   Suburb       Data Scientist
# 227      228   Advait Mukherjee    Male   48     City       Business Owner
# 232      233        Aditya Goel    Male   26     City           Freelancer
# ...

# %%
occupatino_wise_inc_median=df_cust.groupby("occupation").annual_income.median()

# %%
occupatino_wise_inc_median
# Out:
# occupation
# Accountant              65265.0
# Artist                  44915.0
# Business Owner         254881.0
# Consultant              51175.0
# Data Scientist         127889.0
# Freelancer              45189.5
# Fullstack Developer     74457.0
# Name: annual_income, dtype: float64

# %%
for index,row in df_cust.iterrows():
    if row["annual_income"]<100:
        df_cust.at[index,"annual_income"]=occupatino_wise_inc_median[row["occupation"]]

# %%
df_cust[df_cust.annual_income<100]
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %%
df_cust.loc[[14,31]]
# Out:
#     cust_id           name  gender  age location      occupation  \
# 14       15  Sanjana Malik  Female   25    Rural          Artist
# 31       32    Veer Mistry    Male   50     City  Business Owner
#
#     annual_income marital_status
# 14        44915.0        Married
# 31       254881.0        Married

# %% [markdown]
# ### Data Visualization

# %%
avg_income_per_occupation=df_cust.groupby("occupation").annual_income.mean()

# %%
avg_income_per_occupation
# Out:
# occupation
# Accountant              64123.562500
# Artist                  45239.842105
# Business Owner         268119.833910
# Consultant              59927.257732
# Data Scientist         136208.603261
# Freelancer              76293.089912
# Fullstack Developer     78618.385135
# Name: annual_income, dtype: float64

# %%
avg_income_per_occupation.index
# Out:
# Index(['Accountant', 'Artist', 'Business Owner', 'Consultant',
#        'Data Scientist', 'Freelancer', 'Fullstack Developer'],
#       dtype='object', name='occupation')

# %%
avg_income_per_occupation.values
# Out:
# array([ 64123.5625    ,  45239.84210526, 268119.83391003,  59927.25773196,
#        136208.60326087,  76293.08991228,  78618.38513514])

# %% [markdown]
# ### Occupation wise Analysis

# %%
sns.barplot(x=avg_income_per_occupation.index,y=avg_income_per_occupation.values,palette="hls")
plt.title("Occupation wise Analysis")
plt.ylabel("Average Income ($)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Gender wise Analysis

# %%
avg_income_per_gender=df_cust.groupby("gender").annual_income.mean()

# %%
avg_income_per_gender
# Out:
# gender
# Female    129745.226994
# Male      145163.874629
# Name: annual_income, dtype: float64

# %%
avg_income_per_gender.index
# Out:
# Index(['Female', 'Male'], dtype='object', name='gender')

# %%
avg_income_per_gender.values
# Out:
# array([129745.22699387, 145163.87462908])

# %%
sns.barplot(x=avg_income_per_gender.index,y=avg_income_per_gender.values,palette="hls")
plt.ylabel("Average Annual Income in ($)")
plt.show()

# %%
df_cust.location.unique()
# Out:
# array(['City', 'Rural', 'Suburb'], dtype=object)

# %%
avg_income_per_location=df_cust.groupby("location").annual_income.mean()
avg_income_per_location
# Out:
# location
# City      140310.866764
# Rural     124579.800000
# Suburb    145326.683190
# Name: annual_income, dtype: float64

# %%
avg_income_per_location.index
# Out:
# Index(['City', 'Rural', 'Suburb'], dtype='object', name='location')

# %%
avg_income_per_location.values
# Out:
# array([140310.86676428, 124579.8       , 145326.68318966])

# %% [markdown]
# ### Location wise Analysis

# %%
sns.barplot(x=avg_income_per_location.index,y=avg_income_per_location.values,palette="hls")
plt.ylabel("Average Annual Income ($)")
plt.show()

# %% [markdown]
# ### Marital Status wise Analysis

# %%
avg_income_per_martial_status=df_cust.groupby("marital_status").annual_income.mean()
avg_income_per_martial_status
# Out:
# marital_status
# Married    140123.202581
# Single     140186.282222
# Name: annual_income, dtype: float64

# %%
sns.barplot(x=avg_income_per_martial_status.index,y=avg_income_per_martial_status.values,palette="hls")
plt.ylabel("Average Annual Income ($)")
plt.show()

# %% [markdown]
# ### All Analysis in One Time

# %%
columns=["location","gender","occupation","marital_status"]
for col in columns:
    avg_income=df_cust.groupby(col).annual_income.mean()
    plt.figure(figsize=(6,4))
    sns.barplot(x=avg_income.index,y=avg_income.values,palette="hls")
    plt.xticks(rotation=45)
    avg_income=[]

# %% [markdown]
# <h3 style="color:blue;">2. Analyze Age Column</h3>
# first let us check if there are any null values in the Age column

# %%
df_cust.isnull().sum()
# Out:
# cust_id           0
# name              0
# gender            0
# age               0
# location          0
# occupation        0
# annual_income     0
# marital_status    0
# dtype: int64

# %%
df_cust.age.describe()
# Out:
# count    1000.000000
# mean       36.405000
# std        15.666155
# min         1.000000
# 25%        26.000000
# 50%        32.000000
# 75%        46.000000
# max       135.000000
# Name: age, dtype: float64

# %%
plt.hist(df_cust.age,edgecolor="black",bins=20)
plt.show()

# %%
df_cust[(df_cust.age<15 )|(df_cust.age>80)]
# Out:
#      cust_id             name  gender  age location           occupation  \
# 0          1    Manya Acharya  Female    2     City       Business Owner
# 41        42      Aaryan Shah    Male  110     City               Artist
# 165      166        Sia Dutta  Female    1     City           Freelancer
# 174      175     Rohan Sharma    Male  110     City           Freelancer
# 222      223      Arjun Batra    Male  110   Suburb           Freelancer
# 277      278     Aarav Tandon    Male  110     City           Consultant
# 295      296     Ayush Pandey    Male    1    Rural           Accountant
# 325      326       Virat Goel    Male  110     City           Accountant
# 610      611      Rehan Verma    Male  135    Rural       Business Owner
# 692      693        Dhruv Jha    Male    1     City       Business Owner
# 703      704     Aanya Sharma  Female  110     City           Freelancer
# 709      710      Anika Verma  Female  110     City       Data Scientist
# ...
